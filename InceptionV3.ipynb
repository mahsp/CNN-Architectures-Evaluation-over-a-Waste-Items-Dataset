# %%
import time
import torch
import torch.nn as nn
import torch.nn.functional as F
import torchvision.models as models
import torchvision.transforms as transforms
from PIL import Image
import matplotlib.pyplot as plt
import json, io, requests, string
from torch.utils.data.dataset import Dataset
from torchvision import transforms
import pandas as pd
import numpy as np


class CustomDatasetFromImages(Dataset):
    def __init__(self, csv_path):
        """
        Args:
            csv_path (string): path to csv file
            img_path (string): path to the folder where images are
            transform: pytorch transforms for transforms and tensor conversion
        """
        # Transforms
        self.to_tensor = transforms.ToTensor()
        # Read the csv file
        self.data_info = pd.read_csv(csv_path, header=None)
        # First column contains the image paths
        self.image_arr = np.asarray(self.data_info.iloc[:, 0])
        # Second column is the labels
        self.label_arr = np.asarray(self.data_info.iloc[:, 1])
        # Third column is for an operation indicator
        self.operation_arr = np.asarray(self.data_info.iloc[:, 2])
        # Calculate len
        self.data_len = len(self.data_info.index)

    def __getitem__(self, index):
        # Get image name from the pandas df
        single_image_name = self.image_arr[index]
        # Open image
        img_as_img = Image.open(single_image_name)

        # Check if there is an operation
        some_operation = self.operation_arr[index]
        # If there is an operation
        if some_operation:
            # Do some operation on image
            # ...
            # ...
            pass
        # Transform image to tensor
        img_as_tensor = self.to_tensor(img_as_img)

        # Get label(class) of the image based on the cropped pandas column
        single_image_label = self.label_arr[index]

        return (img_as_tensor, single_image_label)

    def __len__(self):
        return self.data_len
if __name__ == "__main__":
    # Define transforms
    
    # Define custom dataset
    train_data = CustomDatasetFromImages("Train0.csv")
    validation_data = CustomDatasetFromImages("Val0.csv")
    
    # Define data loader
#     trainset = torch.utils.data.DataLoader(dataset=train_data,
#                                                     batch_size=100,
#                                                     shuffle=True)
    
#     valset = torch.utils.data.DataLoader(dataset=validation_data,
#                                                     batch_size=100,
#                                                     shuffle=False)
    
    #for images, labels in trainset:
        # Feed the data to the model

# %%
import torchvision
import torchvision.transforms as transforms
from torchvision.datasets import FashionMNIST
import torch.optim as optim

preprocessFn = transforms.Compose(
    [transforms.Resize(299),  # 1. Resize smallest side to 256.
     transforms.CenterCrop(299), # 2. Crop the center 224x224 pixels.
     transforms.ToTensor(),
     transforms.Normalize(mean = [0.485, 0.456, 0.406],  # normalize.
                          std = [0.229, 0.224, 0.225])])
print(type(train_data))
# img = []
# labellist = []
imgtensor = torch.zeros(1768,3,299,299)
labeltensor = torch.LongTensor(1768,1).zero_()
counter = 0
for (i, (inputs, labels)) in enumerate(train_data):
    counter += 1
    art= transforms.ToPILImage()(inputs)
    imgtensor[i,:,:,:] = preprocessFn(art).unsqueeze(0)
#     print(labels)
    labeltensor[i,:] = torch.tensor(labels)
    
imgtensorVal = torch.zeros(328,3,299,299)
labeltensorVal = torch.LongTensor(328,1).zero_()
counter = 0
for (i, (inputs, labels)) in enumerate(validation_data):
    counter += 1
    art= transforms.ToPILImage()(inputs)
    imgtensorVal[i,:,:,:] = preprocessFn(art).unsqueeze(0)
#     print(labels) 
    labeltensorVal[i,:] = torch.tensor(labels)
    
print(counter)
# Load the training, and validation datasets.
# Out:
# <class '__main__.CustomDatasetFromImages'>
# 326

# %%
from random import shuffle

inceptionV3 = models.inception_v3(pretrained=True)
inceptionV3.fc = nn.Linear(2048, 6)
inceptionV3.eval()

for param in inceptionV3.parameters():
    param.requires_grad = False

inceptionV3.fc.requires_grad = True

train_accuracies = []; val_accuracies = []
train_losses = []; val_losses = []

trainset = torch.utils.data.TensorDataset(imgtensor, labeltensor)
valset = torch.utils.data.TensorDataset(imgtensorVal, labeltensorVal)


precision = []
recall = []
y_true = []
y_pred = []
y_score = []
y_allscore = []
predictionstash = []
truthstash = []
score_list = []
label_list = []



fp = [0] * 6
tp = [0] * 6
print(type(imgtensor))
print(imgtensor[0].shape)
listofthelists = []

def train_model(model, loss_fn, batchSize, trainset, valset, optimizer, fatherofthelists):
  ypred = [0]

  # Shuffling is needed in case dataset is not shuffled by default.
  train_loader = torch.utils.data.DataLoader(dataset = trainset,
                                              batch_size = batchSize,
                                              shuffle = True)
#   # We don't need to bach the validation set but let's do it anyway.
  val_loader = torch.utils.data.DataLoader(dataset = valset,
                                             batch_size = batchSize,
                                             shuffle = False) # No need.
  
  # Define number of epochs.
  N = 15

  # log accuracies and losses.
  train_accuracies = []; val_accuracies = []
  train_losses = []; val_losses = []

  # GPU enabling.
  model = model.cuda()
  loss_fn = loss_fn.cuda()


  # Training loop. Please make sure you understand every single line of code below.
  # Go back to some of the previous steps in this lab if necessary.
  for epoch in range(0, N):
      y_true.append([])
      y_pred.append([])
      y_score.append([])
      y_allscore.append([])
      correct = 0.0
      cum_loss = 0.0
      ytrue = []
      # Make a pass over the training data.
      model.train()
      for (i, (inputs, labels)) in enumerate(train_loader):
          
          inputs = inputs.cuda()
          labels = labels.cuda()
          #print(inputs.shape)
          #trans = transforms.ToPILImage()
          #img = transforms.ToPILImage()(inputs)
          #pil_img = trans(inputs)
          #input_img =  preprocessFn(pil_img).unsqueeze(0)
          # Forward pass. (Prediction stage)
          scores, _ = model(inputs)
#           print(labels)
          loss = loss_fn(scores, labels.view(-1))
          
#           print(labels.view(-1))
#           print(scores.shape)
          # Count how many correct in this batch.
          max_scores, max_labels = scores.max(1)
#           y_true[-1].append(labels.view(-1))
#           y_pred[-1].append(max_labels)
#           y_score[-1].append(max_scores)
#           y_allscore[-1].append(scores)
#           print(max_labels)
#           print(labels.view(-1))
          correct += (max_labels == labels.view(-1)).sum().item()
          cum_loss += loss.item()
          ypred = ypred + max_labels.tolist()
#           print(ypred)
            
        
#           for k in range(6):
#                 for j in range(len(labels.view(-1))):
#                     if labels.view(-1)[j] == k:
#                         tp[k] += (max_labels[j] == labels.view(-1)[j]).sum().item()
#                         fp[k] += (max_labels[j] != labels.view(-1)[j]).sum().item()
                
            
                
                
          # Zero the gradients in the network.
          optimizer.zero_grad()

          #Backward pass. (Gradient computation stage)
          loss.backward()

          # Parameter updates (SGD step) -- if done with torch.optim!
          optimizer.step()
          # Parameter updates (SGD step) -- if done manually!
          # for param in model.parameters():
          #   param.data.add_(-learningRate, param.grad)

          # Logging the current results on training.
          if (i + 1) % 10 == 0:
              print('Train-epoch %d. Iteration %05d, Avg-Loss: %.4f, Accuracy: %.4f' % 
                    (epoch, i + 1, cum_loss / (i + 1), correct / ((i + 1) * batchSize)))
      fatherofthelists.append(ypred)
          
      train_accuracies.append(correct / len(trainset))
      train_losses.append(cum_loss / (i + 1))   

      # Make a pass over the validation data.
      correct = 0.0
      cum_loss = 0.0
      model.eval()

      score_list = []
      label_list = []

      for (i, (inputs, labels)) in enumerate(val_loader):
           inputs = inputs.cuda()
           labels = labels.cuda()


#           # Forward pass. (Prediction stage)
           scores = model(inputs)
           cum_loss += loss_fn(scores, labels.view(-1)).item()
           score_list.append(scores.cpu().tolist())
           label_list.append(labels.view(-1).cpu().tolist())
#            # Count how many correct in this batch.
           max_scores, max_labels = scores.max(1)
           correct += (max_labels == labels.view(-1)).sum().item()

      val_accuracies.append(correct / len(valset))
      val_losses.append(cum_loss / (i + 1))
      
      # Logging the current results on validation.
      print('Validation-epoch %d. Avg-Loss: %.4f, Accuracy: %.4f' % 
            (epoch, cum_loss / (i + 1), correct / len(valset)))
    
  fig = plt.figure(figsize = (10, 4))
  fig.suptitle('Inception_V3 Results', fontsize=14, fontweight='bold')
  plt.subplot(1, 2, 1)
  plt.plot(val_losses, 'bo-', label = 'val-loss')
  plt.plot(train_losses, 'ro-', label = 'train-loss') 
  plt.ylabel('loss')
  plt.xlabel('epoch') 
  plt.legend(['validation', 'training'], loc='upper right')

  plt.subplot(1, 2, 2)
  plt.plot(val_accuracies, 'bo-', label = 'val-acc')
  plt.plot(train_accuracies, 'ro-', label = 'train-acc')
  plt.ylabel('accuracy')
  plt.xlabel('epoch')
  plt.legend(['validation', 'training'], loc='lower right')
  plt.show()      


      
model = inceptionV3
loss_fn = nn.CrossEntropyLoss()
    
# Create the model.
import torch.nn.functional as F
# Optimizer.
learningRate = 1e-5
optimizer = optim.Adam(model.parameters(), lr = learningRate)
batchSize = 5

train_model(model, loss_fn, batchSize, trainset, valset, optimizer, listofthelists )
# Out:
# <class 'torch.Tensor'>
# torch.Size([3, 299, 299])
# Train-epoch 0. Iteration 00010, Avg-Loss: 1.8783, Accuracy: 0.1000
# Train-epoch 0. Iteration 00020, Avg-Loss: 1.8388, Accuracy: 0.1300
# Train-epoch 0. Iteration 00030, Avg-Loss: 1.8236, Accuracy: 0.1600
# Train-epoch 0. Iteration 00040, Avg-Loss: 1.8053, Accuracy: 0.1850
# Train-epoch 0. Iteration 00050, Avg-Loss: 1.7879, Accuracy: 0.2200
# Train-epoch 0. Iteration 00060, Avg-Loss: 1.7805, Accuracy: 0.2300
# Train-epoch 0. Iteration 00070, Avg-Loss: 1.7693, Accuracy: 0.2429
# Train-epoch 0. Iteration 00080, Avg-Loss: 1.7596, Accuracy: 0.2475
# Train-epoch 0. Iteration 00090, Avg-Loss: 1.7484, Accuracy: 0.2578
# Train-epoch 0. Iteration 00100, Avg-Loss: 1.7327, Accuracy: 0.2780
# Train-epoch 0. Iteration 00110, Avg-Loss: 1.7206, Accuracy: 0.2982
# Train-epoch 0. Iteration 00120, Avg-Loss: 1.7129, Accuracy: 0.3050
# Train-epoch 0. Iteration 00130, Avg-Loss: 1.7042, Accuracy: 0.3169
# Train-epoch 0. Iteration 00140, Avg-Loss: 1.6947, Accuracy: 0.3257
# Train-epoch 0. Iteration 00150, Avg-Loss: 1.6884, Accuracy: 0.3293
# Train-epoch 0. Iteration 00160, Avg-Loss: 1.6767, Accuracy: 0.3400
# Train-epoch 0. Iteration 00170, Avg-Loss: 1.6704, Accuracy: 0.3424
# Train-epoch 0. Iteration 00180, Avg-Loss: 1.6643, Accuracy: 0.3467
# Train-epoch 0. Iteration 00190, Avg-Loss: 1.6603, Accuracy: 0.3526
# Train-epoch 0. Iteration 00200, Avg-Loss: 1.6486, Accuracy: 0.3610
# Train-epoch 0. Iteration 00210, Avg-Loss: 1.6437, Accuracy: 0.3657
# Train-epoch 0. Iteration 00220, Avg-Loss: 1.6373, Accuracy: 0.3718
# Train-epoch 0. Iteration 00230, Avg-Loss: 1.6286, Accuracy: 0.3800
# Train-epoch 0. Iteration 00240, Avg-Loss: 1.6203, Accuracy: 0.3867
# Train-epoch 0. Iteration 00250, Avg-Loss: 1.6085, Accuracy: 0.3920
# Train-epoch 0. Iteration 00260, Avg-Loss: 1.6003, Accuracy: 0.3969
# Train-epoch 0. Iteration 00270, Avg-Loss: 1.5935, Accuracy: 0.4022
# Train-epoch 0. Iteration 00280, Avg-Loss: 1.5884, Accuracy: 0.4071
# Train-epoch 0. Iteration 00290, Avg-Loss: 1.5816, Accuracy: 0.4103
# Train-epoch 0. Iteration 00300, Avg-Loss: 1.5736, Accuracy: 0.4133
# Train-epoch 0. Iteration 00310, Avg-Loss: 1.5629, Accuracy: 0.4200
# Train-epoch 0. Iteration 00320, Avg-Loss: 1.5522, Accuracy: 0.4269
# Train-epoch 0. Iteration 00330, Avg-Loss: 1.5433, Accuracy: 0.4303
# Train-epoch 0. Iteration 00340, Avg-Loss: 1.5350, Accuracy: 0.4341
# Train-epoch 0. Iteration 00350, Avg-Loss: 1.5259, Accuracy: 0.4400
# Validation-epoch 0. Avg-Loss: 1.1462, Accuracy: 0.6921
# Train-epoch 1. Iteration 00010, Avg-Loss: 1.2303, Accuracy: 0.5200
# Train-epoch 1. Iteration 00020, Avg-Loss: 1.2015, Accuracy: 0.5500
# Train-epoch 1. Iteration 00030, Avg-Loss: 1.2257, Accuracy: 0.5333
# Train-epoch 1. Iteration 00040, Avg-Loss: 1.2150, Accuracy: 0.5700
# Train-epoch 1. Iteration 00050, Avg-Loss: 1.2193, Accuracy: 0.5760
# Train-epoch 1. Iteration 00060, Avg-Loss: 1.2035, Accuracy: 0.5933
# Train-epoch 1. Iteration 00070, Avg-Loss: 1.1993, Accuracy: 0.5886
# Train-epoch 1. Iteration 00080, Avg-Loss: 1.1912, Accuracy: 0.6000
# Train-epoch 1. Iteration 00090, Avg-Loss: 1.2003, Accuracy: 0.5889
# Train-epoch 1. Iteration 00100, Avg-Loss: 1.1961, Accuracy: 0.5940
# Train-epoch 1. Iteration 00110, Avg-Loss: 1.1839, Accuracy: 0.6000
# Train-epoch 1. Iteration 00120, Avg-Loss: 1.1708, Accuracy: 0.6067
# Train-epoch 1. Iteration 00130, Avg-Loss: 1.1770, Accuracy: 0.6000
# Train-epoch 1. Iteration 00140, Avg-Loss: 1.1794, Accuracy: 0.5986
# Train-epoch 1. Iteration 00150, Avg-Loss: 1.1712, Accuracy: 0.6067
# Train-epoch 1. Iteration 00160, Avg-Loss: 1.1688, Accuracy: 0.6038
# Train-epoch 1. Iteration 00170, Avg-Loss: 1.1588, Accuracy: 0.6082
# Train-epoch 1. Iteration 00180, Avg-Loss: 1.1483, Accuracy: 0.6122
# Train-epoch 1. Iteration 00190, Avg-Loss: 1.1426, Accuracy: 0.6168
# Train-epoch 1. Iteration 00200, Avg-Loss: 1.1385, Accuracy: 0.6170
# Train-epoch 1. Iteration 00210, Avg-Loss: 1.1341, Accuracy: 0.6181
# Train-epoch 1. Iteration 00220, Avg-Loss: 1.1370, Accuracy: 0.6173
# Train-epoch 1. Iteration 00230, Avg-Loss: 1.1406, Accuracy: 0.6122
# Train-epoch 1. Iteration 00240, Avg-Loss: 1.1348, Accuracy: 0.6175
# Train-epoch 1. Iteration 00250, Avg-Loss: 1.1260, Accuracy: 0.6216
# Train-epoch 1. Iteration 00260, Avg-Loss: 1.1226, Accuracy: 0.6231
# Train-epoch 1. Iteration 00270, Avg-Loss: 1.1215, Accuracy: 0.6237
# Train-epoch 1. Iteration 00280, Avg-Loss: 1.1165, Accuracy: 0.6214
# Train-epoch 1. Iteration 00290, Avg-Loss: 1.1130, Accuracy: 0.6221
# Train-epoch 1. Iteration 00300, Avg-Loss: 1.1112, Accuracy: 0.6220
# Train-epoch 1. Iteration 00310, Avg-Loss: 1.1021, Accuracy: 0.6245
# Train-epoch 1. Iteration 00320, Avg-Loss: 1.0981, Accuracy: 0.6262
# Train-epoch 1. Iteration 00330, Avg-Loss: 1.0950, Accuracy: 0.6279
# Train-epoch 1. Iteration 00340, Avg-Loss: 1.0923, Accuracy: 0.6282
# Train-epoch 1. Iteration 00350, Avg-Loss: 1.0894, Accuracy: 0.6291
# Validation-epoch 1. Avg-Loss: 0.8191, Accuracy: 0.7500
# Train-epoch 2. Iteration 00010, Avg-Loss: 1.0667, Accuracy: 0.6600
# Train-epoch 2. Iteration 00020, Avg-Loss: 1.0055, Accuracy: 0.6500
# Train-epoch 2. Iteration 00030, Avg-Loss: 0.9858, Accuracy: 0.6800
# Train-epoch 2. Iteration 00040, Avg-Loss: 0.9835, Accuracy: 0.6950
# Train-epoch 2. Iteration 00050, Avg-Loss: 0.9773, Accuracy: 0.6960
# Train-epoch 2. Iteration 00060, Avg-Loss: 0.9606, Accuracy: 0.7033
# Train-epoch 2. Iteration 00070, Avg-Loss: 0.9416, Accuracy: 0.7057
# Train-epoch 2. Iteration 00080, Avg-Loss: 0.9279, Accuracy: 0.7125
# Train-epoch 2. Iteration 00090, Avg-Loss: 0.9213, Accuracy: 0.7156
# Train-epoch 2. Iteration 00100, Avg-Loss: 0.9192, Accuracy: 0.7120
# Train-epoch 2. Iteration 00110, Avg-Loss: 0.9230, Accuracy: 0.7055
# Train-epoch 2. Iteration 00120, Avg-Loss: 0.9170, Accuracy: 0.7067
# Train-epoch 2. Iteration 00130, Avg-Loss: 0.9157, Accuracy: 0.7031
# Train-epoch 2. Iteration 00140, Avg-Loss: 0.9125, Accuracy: 0.7029
# Train-epoch 2. Iteration 00150, Avg-Loss: 0.9105, Accuracy: 0.7067
# Train-epoch 2. Iteration 00160, Avg-Loss: 0.9066, Accuracy: 0.7100
# Train-epoch 2. Iteration 00170, Avg-Loss: 0.9100, Accuracy: 0.7035
# Train-epoch 2. Iteration 00180, Avg-Loss: 0.9034, Accuracy: 0.7089
# Train-epoch 2. Iteration 00190, Avg-Loss: 0.8897, Accuracy: 0.7168
# Train-epoch 2. Iteration 00200, Avg-Loss: 0.8857, Accuracy: 0.7180
# Train-epoch 2. Iteration 00210, Avg-Loss: 0.8776, Accuracy: 0.7219
# Train-epoch 2. Iteration 00220, Avg-Loss: 0.8806, Accuracy: 0.7209
# Train-epoch 2. Iteration 00230, Avg-Loss: 0.8785, Accuracy: 0.7226
# Train-epoch 2. Iteration 00240, Avg-Loss: 0.8772, Accuracy: 0.7233
# Train-epoch 2. Iteration 00250, Avg-Loss: 0.8691, Accuracy: 0.7256
# Train-epoch 2. Iteration 00260, Avg-Loss: 0.8673, Accuracy: 0.7262
# Train-epoch 2. Iteration 00270, Avg-Loss: 0.8570, Accuracy: 0.7281
# Train-epoch 2. Iteration 00280, Avg-Loss: 0.8508, Accuracy: 0.7307
# Train-epoch 2. Iteration 00290, Avg-Loss: 0.8488, Accuracy: 0.7331
# Train-epoch 2. Iteration 00300, Avg-Loss: 0.8431, Accuracy: 0.7347
# Train-epoch 2. Iteration 00310, Avg-Loss: 0.8400, Accuracy: 0.7355
# Train-epoch 2. Iteration 00320, Avg-Loss: 0.8371, Accuracy: 0.7375
# Train-epoch 2. Iteration 00330, Avg-Loss: 0.8422, Accuracy: 0.7345
# Train-epoch 2. Iteration 00340, Avg-Loss: 0.8416, Accuracy: 0.7347
# Train-epoch 2. Iteration 00350, Avg-Loss: 0.8386, Accuracy: 0.7360
# Validation-epoch 2. Avg-Loss: 0.6188, Accuracy: 0.8232
# Train-epoch 3. Iteration 00010, Avg-Loss: 0.9024, Accuracy: 0.7400
# Train-epoch 3. Iteration 00020, Avg-Loss: 0.8150, Accuracy: 0.7700
# Train-epoch 3. Iteration 00030, Avg-Loss: 0.7674, Accuracy: 0.7933
# Train-epoch 3. Iteration 00040, Avg-Loss: 0.8164, Accuracy: 0.7600
# Train-epoch 3. Iteration 00050, Avg-Loss: 0.7827, Accuracy: 0.7640
# Train-epoch 3. Iteration 00060, Avg-Loss: 0.7922, Accuracy: 0.7467
# Train-epoch 3. Iteration 00070, Avg-Loss: 0.7906, Accuracy: 0.7457
# Train-epoch 3. Iteration 00080, Avg-Loss: 0.7988, Accuracy: 0.7400
# Train-epoch 3. Iteration 00090, Avg-Loss: 0.7917, Accuracy: 0.7444
# Train-epoch 3. Iteration 00100, Avg-Loss: 0.7883, Accuracy: 0.7480
# Train-epoch 3. Iteration 00110, Avg-Loss: 0.7820, Accuracy: 0.7473
# Train-epoch 3. Iteration 00120, Avg-Loss: 0.7910, Accuracy: 0.7417
# Train-epoch 3. Iteration 00130, Avg-Loss: 0.7942, Accuracy: 0.7431
# Train-epoch 3. Iteration 00140, Avg-Loss: 0.7871, Accuracy: 0.7486
# Train-epoch 3. Iteration 00150, Avg-Loss: 0.7800, Accuracy: 0.7533
# Train-epoch 3. Iteration 00160, Avg-Loss: 0.7769, Accuracy: 0.7562
# Train-epoch 3. Iteration 00170, Avg-Loss: 0.7738, Accuracy: 0.7576
# Train-epoch 3. Iteration 00180, Avg-Loss: 0.7660, Accuracy: 0.7600
# Train-epoch 3. Iteration 00190, Avg-Loss: 0.7599, Accuracy: 0.7600
# Train-epoch 3. Iteration 00200, Avg-Loss: 0.7569, Accuracy: 0.7610
# Train-epoch 3. Iteration 00210, Avg-Loss: 0.7516, Accuracy: 0.7610
# Train-epoch 3. Iteration 00220, Avg-Loss: 0.7444, Accuracy: 0.7627
# Train-epoch 3. Iteration 00230, Avg-Loss: 0.7442, Accuracy: 0.7626
# Train-epoch 3. Iteration 00240, Avg-Loss: 0.7433, Accuracy: 0.7625
# Train-epoch 3. Iteration 00250, Avg-Loss: 0.7357, Accuracy: 0.7672
# Train-epoch 3. Iteration 00260, Avg-Loss: 0.7301, Accuracy: 0.7700
# Train-epoch 3. Iteration 00270, Avg-Loss: 0.7359, Accuracy: 0.7667
# Train-epoch 3. Iteration 00280, Avg-Loss: 0.7280, Accuracy: 0.7686
# Train-epoch 3. Iteration 00290, Avg-Loss: 0.7272, Accuracy: 0.7690
# Train-epoch 3. Iteration 00300, Avg-Loss: 0.7281, Accuracy: 0.7673
# Train-epoch 3. Iteration 00310, Avg-Loss: 0.7336, Accuracy: 0.7639
# Train-epoch 3. Iteration 00320, Avg-Loss: 0.7335, Accuracy: 0.7644
# Train-epoch 3. Iteration 00330, Avg-Loss: 0.7302, Accuracy: 0.7655
# Train-epoch 3. Iteration 00340, Avg-Loss: 0.7233, Accuracy: 0.7700
# Train-epoch 3. Iteration 00350, Avg-Loss: 0.7180, Accuracy: 0.7726
# Validation-epoch 3. Avg-Loss: 0.5112, Accuracy: 0.8506
# Train-epoch 4. Iteration 00010, Avg-Loss: 0.5736, Accuracy: 0.7800
# Train-epoch 4. Iteration 00020, Avg-Loss: 0.5663, Accuracy: 0.8100
# Train-epoch 4. Iteration 00030, Avg-Loss: 0.5703, Accuracy: 0.8267
# Train-epoch 4. Iteration 00040, Avg-Loss: 0.5937, Accuracy: 0.8200
# Train-epoch 4. Iteration 00050, Avg-Loss: 0.5907, Accuracy: 0.8080
# Train-epoch 4. Iteration 00060, Avg-Loss: 0.5988, Accuracy: 0.8100
# Train-epoch 4. Iteration 00070, Avg-Loss: 0.5963, Accuracy: 0.8200
# Train-epoch 4. Iteration 00080, Avg-Loss: 0.5803, Accuracy: 0.8300
# Train-epoch 4. Iteration 00090, Avg-Loss: 0.5891, Accuracy: 0.8222
# Train-epoch 4. Iteration 00100, Avg-Loss: 0.5898, Accuracy: 0.8220
# Train-epoch 4. Iteration 00110, Avg-Loss: 0.5885, Accuracy: 0.8200
# Train-epoch 4. Iteration 00120, Avg-Loss: 0.5978, Accuracy: 0.8133
# Train-epoch 4. Iteration 00130, Avg-Loss: 0.6007, Accuracy: 0.8077
# Train-epoch 4. Iteration 00140, Avg-Loss: 0.6107, Accuracy: 0.8000
# Train-epoch 4. Iteration 00150, Avg-Loss: 0.6078, Accuracy: 0.8000
# Train-epoch 4. Iteration 00160, Avg-Loss: 0.6083, Accuracy: 0.7987
# Train-epoch 4. Iteration 00170, Avg-Loss: 0.5987, Accuracy: 0.8047
# Train-epoch 4. Iteration 00180, Avg-Loss: 0.5911, Accuracy: 0.8100
# Train-epoch 4. Iteration 00190, Avg-Loss: 0.5923, Accuracy: 0.8105
# Train-epoch 4. Iteration 00200, Avg-Loss: 0.6008, Accuracy: 0.8080
# Train-epoch 4. Iteration 00210, Avg-Loss: 0.6054, Accuracy: 0.8048
# Train-epoch 4. Iteration 00220, Avg-Loss: 0.6024, Accuracy: 0.8073
# Train-epoch 4. Iteration 00230, Avg-Loss: 0.6021, Accuracy: 0.8052
# Train-epoch 4. Iteration 00240, Avg-Loss: 0.5957, Accuracy: 0.8092
# Train-epoch 4. Iteration 00250, Avg-Loss: 0.5938, Accuracy: 0.8096
# Train-epoch 4. Iteration 00260, Avg-Loss: 0.5879, Accuracy: 0.8138
# Train-epoch 4. Iteration 00270, Avg-Loss: 0.5816, Accuracy: 0.8163
# Train-epoch 4. Iteration 00280, Avg-Loss: 0.5749, Accuracy: 0.8207
# Train-epoch 4. Iteration 00290, Avg-Loss: 0.5797, Accuracy: 0.8186
# Train-epoch 4. Iteration 00300, Avg-Loss: 0.5756, Accuracy: 0.8207
# Train-epoch 4. Iteration 00310, Avg-Loss: 0.5716, Accuracy: 0.8226
# Train-epoch 4. Iteration 00320, Avg-Loss: 0.5639, Accuracy: 0.8263
# Train-epoch 4. Iteration 00330, Avg-Loss: 0.5600, Accuracy: 0.8285
# Train-epoch 4. Iteration 00340, Avg-Loss: 0.5595, Accuracy: 0.8294
# Train-epoch 4. Iteration 00350, Avg-Loss: 0.5607, Accuracy: 0.8269
# Validation-epoch 4. Avg-Loss: 0.4353, Accuracy: 0.8689
# Train-epoch 5. Iteration 00010, Avg-Loss: 0.5372, Accuracy: 0.8600
# Train-epoch 5. Iteration 00020, Avg-Loss: 0.5048, Accuracy: 0.8700
# Train-epoch 5. Iteration 00030, Avg-Loss: 0.5284, Accuracy: 0.8600
# Train-epoch 5. Iteration 00040, Avg-Loss: 0.4864, Accuracy: 0.8650
# Train-epoch 5. Iteration 00050, Avg-Loss: 0.4639, Accuracy: 0.8680
# Train-epoch 5. Iteration 00060, Avg-Loss: 0.4629, Accuracy: 0.8733
# Train-epoch 5. Iteration 00070, Avg-Loss: 0.4385, Accuracy: 0.8829
# Train-epoch 5. Iteration 00080, Avg-Loss: 0.4594, Accuracy: 0.8725
# Train-epoch 5. Iteration 00090, Avg-Loss: 0.4414, Accuracy: 0.8800
# Train-epoch 5. Iteration 00100, Avg-Loss: 0.4400, Accuracy: 0.8820
# Train-epoch 5. Iteration 00110, Avg-Loss: 0.4412, Accuracy: 0.8818
# Train-epoch 5. Iteration 00120, Avg-Loss: 0.4490, Accuracy: 0.8750
# Train-epoch 5. Iteration 00130, Avg-Loss: 0.4480, Accuracy: 0.8754
# Train-epoch 5. Iteration 00140, Avg-Loss: 0.4487, Accuracy: 0.8800
# Train-epoch 5. Iteration 00150, Avg-Loss: 0.4464, Accuracy: 0.8813
# Train-epoch 5. Iteration 00160, Avg-Loss: 0.4454, Accuracy: 0.8775
# Train-epoch 5. Iteration 00170, Avg-Loss: 0.4557, Accuracy: 0.8729
# Train-epoch 5. Iteration 00180, Avg-Loss: 0.4569, Accuracy: 0.8722
# Train-epoch 5. Iteration 00190, Avg-Loss: 0.4720, Accuracy: 0.8642
# Train-epoch 5. Iteration 00200, Avg-Loss: 0.4719, Accuracy: 0.8640
# Train-epoch 5. Iteration 00210, Avg-Loss: 0.4701, Accuracy: 0.8657
# Train-epoch 5. Iteration 00220, Avg-Loss: 0.4672, Accuracy: 0.8691
# Train-epoch 5. Iteration 00230, Avg-Loss: 0.4706, Accuracy: 0.8678
# Train-epoch 5. Iteration 00240, Avg-Loss: 0.4806, Accuracy: 0.8642
# Train-epoch 5. Iteration 00250, Avg-Loss: 0.4752, Accuracy: 0.8656
# Train-epoch 5. Iteration 00260, Avg-Loss: 0.4697, Accuracy: 0.8685
# Train-epoch 5. Iteration 00270, Avg-Loss: 0.4699, Accuracy: 0.8659
# Train-epoch 5. Iteration 00280, Avg-Loss: 0.4729, Accuracy: 0.8629
# Train-epoch 5. Iteration 00290, Avg-Loss: 0.4736, Accuracy: 0.8621
# Train-epoch 5. Iteration 00300, Avg-Loss: 0.4798, Accuracy: 0.8600
# Train-epoch 5. Iteration 00310, Avg-Loss: 0.4730, Accuracy: 0.8632
# Train-epoch 5. Iteration 00320, Avg-Loss: 0.4778, Accuracy: 0.8600
# Train-epoch 5. Iteration 00330, Avg-Loss: 0.4786, Accuracy: 0.8576
# Train-epoch 5. Iteration 00340, Avg-Loss: 0.4724, Accuracy: 0.8618
# Train-epoch 5. Iteration 00350, Avg-Loss: 0.4701, Accuracy: 0.8623
# Validation-epoch 5. Avg-Loss: 0.4050, Accuracy: 0.8780
# Train-epoch 6. Iteration 00010, Avg-Loss: 0.4213, Accuracy: 0.8400
# Train-epoch 6. Iteration 00020, Avg-Loss: 0.3458, Accuracy: 0.8800
# Train-epoch 6. Iteration 00030, Avg-Loss: 0.4306, Accuracy: 0.8533
# Train-epoch 6. Iteration 00040, Avg-Loss: 0.4458, Accuracy: 0.8450
# Train-epoch 6. Iteration 00050, Avg-Loss: 0.4430, Accuracy: 0.8400
# Train-epoch 6. Iteration 00060, Avg-Loss: 0.4262, Accuracy: 0.8433
# Train-epoch 6. Iteration 00070, Avg-Loss: 0.4252, Accuracy: 0.8457
# Train-epoch 6. Iteration 00080, Avg-Loss: 0.4201, Accuracy: 0.8525
# Train-epoch 6. Iteration 00090, Avg-Loss: 0.4111, Accuracy: 0.8556
# Train-epoch 6. Iteration 00100, Avg-Loss: 0.4132, Accuracy: 0.8600
# Train-epoch 6. Iteration 00110, Avg-Loss: 0.4133, Accuracy: 0.8618
# Train-epoch 6. Iteration 00120, Avg-Loss: 0.4057, Accuracy: 0.8683
# Train-epoch 6. Iteration 00130, Avg-Loss: 0.4065, Accuracy: 0.8708
# Train-epoch 6. Iteration 00140, Avg-Loss: 0.4133, Accuracy: 0.8671
# Train-epoch 6. Iteration 00150, Avg-Loss: 0.4161, Accuracy: 0.8653
# Train-epoch 6. Iteration 00160, Avg-Loss: 0.4203, Accuracy: 0.8650
# Train-epoch 6. Iteration 00170, Avg-Loss: 0.4211, Accuracy: 0.8671
# Train-epoch 6. Iteration 00180, Avg-Loss: 0.4232, Accuracy: 0.8656
# Train-epoch 6. Iteration 00190, Avg-Loss: 0.4228, Accuracy: 0.8663
# Train-epoch 6. Iteration 00200, Avg-Loss: 0.4269, Accuracy: 0.8670
# Train-epoch 6. Iteration 00210, Avg-Loss: 0.4260, Accuracy: 0.8686
# Train-epoch 6. Iteration 00220, Avg-Loss: 0.4243, Accuracy: 0.8691
# Train-epoch 6. Iteration 00230, Avg-Loss: 0.4269, Accuracy: 0.8687
# Train-epoch 6. Iteration 00240, Avg-Loss: 0.4223, Accuracy: 0.8708
# Train-epoch 6. Iteration 00250, Avg-Loss: 0.4216, Accuracy: 0.8712
# Train-epoch 6. Iteration 00260, Avg-Loss: 0.4173, Accuracy: 0.8738
# Train-epoch 6. Iteration 00270, Avg-Loss: 0.4176, Accuracy: 0.8741
# Train-epoch 6. Iteration 00280, Avg-Loss: 0.4138, Accuracy: 0.8757
# Train-epoch 6. Iteration 00290, Avg-Loss: 0.4152, Accuracy: 0.8745
# Train-epoch 6. Iteration 00300, Avg-Loss: 0.4128, Accuracy: 0.8767
# Train-epoch 6. Iteration 00310, Avg-Loss: 0.4139, Accuracy: 0.8761
# Train-epoch 6. Iteration 00320, Avg-Loss: 0.4096, Accuracy: 0.8788
# Train-epoch 6. Iteration 00330, Avg-Loss: 0.4091, Accuracy: 0.8800
# Train-epoch 6. Iteration 00340, Avg-Loss: 0.4106, Accuracy: 0.8788
# Train-epoch 6. Iteration 00350, Avg-Loss: 0.4104, Accuracy: 0.8789
# Validation-epoch 6. Avg-Loss: 0.3597, Accuracy: 0.8750
# Train-epoch 7. Iteration 00010, Avg-Loss: 0.3463, Accuracy: 0.9200
# Train-epoch 7. Iteration 00020, Avg-Loss: 0.4361, Accuracy: 0.8800
# Train-epoch 7. Iteration 00030, Avg-Loss: 0.4015, Accuracy: 0.8933
# Train-epoch 7. Iteration 00040, Avg-Loss: 0.3686, Accuracy: 0.9050
# Train-epoch 7. Iteration 00050, Avg-Loss: 0.3699, Accuracy: 0.9000
# Train-epoch 7. Iteration 00060, Avg-Loss: 0.3769, Accuracy: 0.9000
# Train-epoch 7. Iteration 00070, Avg-Loss: 0.3700, Accuracy: 0.9000
# Train-epoch 7. Iteration 00080, Avg-Loss: 0.3596, Accuracy: 0.9000
# Train-epoch 7. Iteration 00090, Avg-Loss: 0.3571, Accuracy: 0.8978
# Train-epoch 7. Iteration 00100, Avg-Loss: 0.3515, Accuracy: 0.8980
# Train-epoch 7. Iteration 00110, Avg-Loss: 0.3514, Accuracy: 0.9000
# Train-epoch 7. Iteration 00120, Avg-Loss: 0.3416, Accuracy: 0.9067
# Train-epoch 7. Iteration 00130, Avg-Loss: 0.3449, Accuracy: 0.9077
# Train-epoch 7. Iteration 00140, Avg-Loss: 0.3337, Accuracy: 0.9143
# Train-epoch 7. Iteration 00150, Avg-Loss: 0.3299, Accuracy: 0.9147
# Train-epoch 7. Iteration 00160, Avg-Loss: 0.3242, Accuracy: 0.9150
# Train-epoch 7. Iteration 00170, Avg-Loss: 0.3248, Accuracy: 0.9141
# Train-epoch 7. Iteration 00180, Avg-Loss: 0.3292, Accuracy: 0.9111
# Train-epoch 7. Iteration 00190, Avg-Loss: 0.3331, Accuracy: 0.9084
# Train-epoch 7. Iteration 00200, Avg-Loss: 0.3291, Accuracy: 0.9120
# Train-epoch 7. Iteration 00210, Avg-Loss: 0.3252, Accuracy: 0.9133
# Train-epoch 7. Iteration 00220, Avg-Loss: 0.3208, Accuracy: 0.9155
# Train-epoch 7. Iteration 00230, Avg-Loss: 0.3248, Accuracy: 0.9148
# Train-epoch 7. Iteration 00240, Avg-Loss: 0.3238, Accuracy: 0.9150
# Train-epoch 7. Iteration 00250, Avg-Loss: 0.3237, Accuracy: 0.9144
# Train-epoch 7. Iteration 00260, Avg-Loss: 0.3271, Accuracy: 0.9123
# Train-epoch 7. Iteration 00270, Avg-Loss: 0.3235, Accuracy: 0.9133
# Train-epoch 7. Iteration 00280, Avg-Loss: 0.3239, Accuracy: 0.9121
# Train-epoch 7. Iteration 00290, Avg-Loss: 0.3206, Accuracy: 0.9131
# Train-epoch 7. Iteration 00300, Avg-Loss: 0.3187, Accuracy: 0.9140
# Train-epoch 7. Iteration 00310, Avg-Loss: 0.3231, Accuracy: 0.9116
# Train-epoch 7. Iteration 00320, Avg-Loss: 0.3225, Accuracy: 0.9113
# Train-epoch 7. Iteration 00330, Avg-Loss: 0.3282, Accuracy: 0.9079
# Train-epoch 7. Iteration 00340, Avg-Loss: 0.3259, Accuracy: 0.9088
# Train-epoch 7. Iteration 00350, Avg-Loss: 0.3236, Accuracy: 0.9109
# Validation-epoch 7. Avg-Loss: 0.3593, Accuracy: 0.8872
# Train-epoch 8. Iteration 00010, Avg-Loss: 0.2403, Accuracy: 0.9200
# Train-epoch 8. Iteration 00020, Avg-Loss: 0.2554, Accuracy: 0.9300
# Train-epoch 8. Iteration 00030, Avg-Loss: 0.2984, Accuracy: 0.9200
# Train-epoch 8. Iteration 00040, Avg-Loss: 0.2713, Accuracy: 0.9350
# Train-epoch 8. Iteration 00050, Avg-Loss: 0.2699, Accuracy: 0.9320
# Train-epoch 8. Iteration 00060, Avg-Loss: 0.2822, Accuracy: 0.9267
# Train-epoch 8. Iteration 00070, Avg-Loss: 0.2896, Accuracy: 0.9229
# Train-epoch 8. Iteration 00080, Avg-Loss: 0.2836, Accuracy: 0.9225
# Train-epoch 8. Iteration 00090, Avg-Loss: 0.2889, Accuracy: 0.9267
# Train-epoch 8. Iteration 00100, Avg-Loss: 0.2834, Accuracy: 0.9280
# Train-epoch 8. Iteration 00110, Avg-Loss: 0.2775, Accuracy: 0.9291
# Train-epoch 8. Iteration 00120, Avg-Loss: 0.2681, Accuracy: 0.9317
# Train-epoch 8. Iteration 00130, Avg-Loss: 0.2816, Accuracy: 0.9262
# Train-epoch 8. Iteration 00140, Avg-Loss: 0.2764, Accuracy: 0.9271
# Train-epoch 8. Iteration 00150, Avg-Loss: 0.2770, Accuracy: 0.9267
# Train-epoch 8. Iteration 00160, Avg-Loss: 0.2817, Accuracy: 0.9250
# Train-epoch 8. Iteration 00170, Avg-Loss: 0.2802, Accuracy: 0.9259
# Train-epoch 8. Iteration 00180, Avg-Loss: 0.2744, Accuracy: 0.9289
# Train-epoch 8. Iteration 00190, Avg-Loss: 0.2742, Accuracy: 0.9295
# Train-epoch 8. Iteration 00200, Avg-Loss: 0.2703, Accuracy: 0.9320
# Train-epoch 8. Iteration 00210, Avg-Loss: 0.2717, Accuracy: 0.9324
# Train-epoch 8. Iteration 00220, Avg-Loss: 0.2711, Accuracy: 0.9318
# Train-epoch 8. Iteration 00230, Avg-Loss: 0.2670, Accuracy: 0.9330
# Train-epoch 8. Iteration 00240, Avg-Loss: 0.2694, Accuracy: 0.9325
# Train-epoch 8. Iteration 00250, Avg-Loss: 0.2704, Accuracy: 0.9304
# Train-epoch 8. Iteration 00260, Avg-Loss: 0.2696, Accuracy: 0.9308
# Train-epoch 8. Iteration 00270, Avg-Loss: 0.2667, Accuracy: 0.9326
# Train-epoch 8. Iteration 00280, Avg-Loss: 0.2662, Accuracy: 0.9329
# Train-epoch 8. Iteration 00290, Avg-Loss: 0.2671, Accuracy: 0.9331
# Train-epoch 8. Iteration 00300, Avg-Loss: 0.2673, Accuracy: 0.9320
# Train-epoch 8. Iteration 00310, Avg-Loss: 0.2681, Accuracy: 0.9323
# Train-epoch 8. Iteration 00320, Avg-Loss: 0.2686, Accuracy: 0.9331
# Train-epoch 8. Iteration 00330, Avg-Loss: 0.2676, Accuracy: 0.9327
# Train-epoch 8. Iteration 00340, Avg-Loss: 0.2702, Accuracy: 0.9318
# Train-epoch 8. Iteration 00350, Avg-Loss: 0.2667, Accuracy: 0.9337
# Validation-epoch 8. Avg-Loss: 0.3278, Accuracy: 0.9024
# Train-epoch 9. Iteration 00010, Avg-Loss: 0.1437, Accuracy: 0.9800
# Train-epoch 9. Iteration 00020, Avg-Loss: 0.3739, Accuracy: 0.9100
# Train-epoch 9. Iteration 00030, Avg-Loss: 0.3304, Accuracy: 0.9267
# Train-epoch 9. Iteration 00040, Avg-Loss: 0.3120, Accuracy: 0.9150
# Train-epoch 9. Iteration 00050, Avg-Loss: 0.3009, Accuracy: 0.9200
# Train-epoch 9. Iteration 00060, Avg-Loss: 0.2782, Accuracy: 0.9333
# Train-epoch 9. Iteration 00070, Avg-Loss: 0.2751, Accuracy: 0.9343
# Train-epoch 9. Iteration 00080, Avg-Loss: 0.2665, Accuracy: 0.9350
# Train-epoch 9. Iteration 00090, Avg-Loss: 0.2712, Accuracy: 0.9311
# Train-epoch 9. Iteration 00100, Avg-Loss: 0.2769, Accuracy: 0.9260
# Train-epoch 9. Iteration 00110, Avg-Loss: 0.2768, Accuracy: 0.9255
# Train-epoch 9. Iteration 00120, Avg-Loss: 0.2747, Accuracy: 0.9300
# Train-epoch 9. Iteration 00130, Avg-Loss: 0.2709, Accuracy: 0.9308
# Train-epoch 9. Iteration 00140, Avg-Loss: 0.2707, Accuracy: 0.9314
# Train-epoch 9. Iteration 00150, Avg-Loss: 0.2608, Accuracy: 0.9360
# Train-epoch 9. Iteration 00160, Avg-Loss: 0.2568, Accuracy: 0.9375
# Train-epoch 9. Iteration 00170, Avg-Loss: 0.2514, Accuracy: 0.9400
# Train-epoch 9. Iteration 00180, Avg-Loss: 0.2486, Accuracy: 0.9400
# Train-epoch 9. Iteration 00190, Avg-Loss: 0.2510, Accuracy: 0.9400
# Train-epoch 9. Iteration 00200, Avg-Loss: 0.2496, Accuracy: 0.9410
# Train-epoch 9. Iteration 00210, Avg-Loss: 0.2455, Accuracy: 0.9419
# Train-epoch 9. Iteration 00220, Avg-Loss: 0.2445, Accuracy: 0.9427
# Train-epoch 9. Iteration 00230, Avg-Loss: 0.2428, Accuracy: 0.9426
# Train-epoch 9. Iteration 00240, Avg-Loss: 0.2441, Accuracy: 0.9425
# Train-epoch 9. Iteration 00250, Avg-Loss: 0.2426, Accuracy: 0.9432
# Train-epoch 9. Iteration 00260, Avg-Loss: 0.2410, Accuracy: 0.9431
# Train-epoch 9. Iteration 00270, Avg-Loss: 0.2367, Accuracy: 0.9444
# Train-epoch 9. Iteration 00280, Avg-Loss: 0.2347, Accuracy: 0.9457
# Train-epoch 9. Iteration 00290, Avg-Loss: 0.2355, Accuracy: 0.9455
# Train-epoch 9. Iteration 00300, Avg-Loss: 0.2362, Accuracy: 0.9453
# Train-epoch 9. Iteration 00310, Avg-Loss: 0.2372, Accuracy: 0.9458
# Train-epoch 9. Iteration 00320, Avg-Loss: 0.2375, Accuracy: 0.9444
# Train-epoch 9. Iteration 00330, Avg-Loss: 0.2376, Accuracy: 0.9442
# Train-epoch 9. Iteration 00340, Avg-Loss: 0.2401, Accuracy: 0.9429
# Train-epoch 9. Iteration 00350, Avg-Loss: 0.2407, Accuracy: 0.9429
# Validation-epoch 9. Avg-Loss: 0.3337, Accuracy: 0.8720
# Train-epoch 10. Iteration 00010, Avg-Loss: 0.2047, Accuracy: 0.9800
# Train-epoch 10. Iteration 00020, Avg-Loss: 0.1742, Accuracy: 0.9800
# Train-epoch 10. Iteration 00030, Avg-Loss: 0.2093, Accuracy: 0.9467
# Train-epoch 10. Iteration 00040, Avg-Loss: 0.1784, Accuracy: 0.9600
# Train-epoch 10. Iteration 00050, Avg-Loss: 0.1786, Accuracy: 0.9640
# Train-epoch 10. Iteration 00060, Avg-Loss: 0.1899, Accuracy: 0.9633
# Train-epoch 10. Iteration 00070, Avg-Loss: 0.1983, Accuracy: 0.9600
# Train-epoch 10. Iteration 00080, Avg-Loss: 0.1938, Accuracy: 0.9600
# Train-epoch 10. Iteration 00090, Avg-Loss: 0.2011, Accuracy: 0.9622
# Train-epoch 10. Iteration 00100, Avg-Loss: 0.2050, Accuracy: 0.9560
# Train-epoch 10. Iteration 00110, Avg-Loss: 0.2027, Accuracy: 0.9564
# Train-epoch 10. Iteration 00120, Avg-Loss: 0.2116, Accuracy: 0.9533
# Train-epoch 10. Iteration 00130, Avg-Loss: 0.2106, Accuracy: 0.9523
# Train-epoch 10. Iteration 00140, Avg-Loss: 0.2158, Accuracy: 0.9500
# Train-epoch 10. Iteration 00150, Avg-Loss: 0.2134, Accuracy: 0.9507
# Train-epoch 10. Iteration 00160, Avg-Loss: 0.2077, Accuracy: 0.9525
# Train-epoch 10. Iteration 00170, Avg-Loss: 0.2072, Accuracy: 0.9529
# Train-epoch 10. Iteration 00180, Avg-Loss: 0.2107, Accuracy: 0.9522
# Train-epoch 10. Iteration 00190, Avg-Loss: 0.2086, Accuracy: 0.9537
# Train-epoch 10. Iteration 00200, Avg-Loss: 0.2057, Accuracy: 0.9550
# Train-epoch 10. Iteration 00210, Avg-Loss: 0.2033, Accuracy: 0.9562
# Train-epoch 10. Iteration 00220, Avg-Loss: 0.2074, Accuracy: 0.9536
# Train-epoch 10. Iteration 00230, Avg-Loss: 0.2029, Accuracy: 0.9548
# Train-epoch 10. Iteration 00240, Avg-Loss: 0.2056, Accuracy: 0.9542
# Train-epoch 10. Iteration 00250, Avg-Loss: 0.2065, Accuracy: 0.9528
# Train-epoch 10. Iteration 00260, Avg-Loss: 0.2126, Accuracy: 0.9500
# Train-epoch 10. Iteration 00270, Avg-Loss: 0.2110, Accuracy: 0.9519
# Train-epoch 10. Iteration 00280, Avg-Loss: 0.2173, Accuracy: 0.9500
# Train-epoch 10. Iteration 00290, Avg-Loss: 0.2231, Accuracy: 0.9469
# Train-epoch 10. Iteration 00300, Avg-Loss: 0.2216, Accuracy: 0.9480
# Train-epoch 10. Iteration 00310, Avg-Loss: 0.2179, Accuracy: 0.9490
# Train-epoch 10. Iteration 00320, Avg-Loss: 0.2158, Accuracy: 0.9494
# Train-epoch 10. Iteration 00330, Avg-Loss: 0.2153, Accuracy: 0.9497
# Train-epoch 10. Iteration 00340, Avg-Loss: 0.2122, Accuracy: 0.9512
# Train-epoch 10. Iteration 00350, Avg-Loss: 0.2101, Accuracy: 0.9520
# Validation-epoch 10. Avg-Loss: 0.3357, Accuracy: 0.8872
# Train-epoch 11. Iteration 00010, Avg-Loss: 0.1184, Accuracy: 1.0000
# Train-epoch 11. Iteration 00020, Avg-Loss: 0.1048, Accuracy: 1.0000
# Train-epoch 11. Iteration 00030, Avg-Loss: 0.1514, Accuracy: 0.9800
# Train-epoch 11. Iteration 00040, Avg-Loss: 0.1500, Accuracy: 0.9800
# Train-epoch 11. Iteration 00050, Avg-Loss: 0.1430, Accuracy: 0.9800
# Train-epoch 11. Iteration 00060, Avg-Loss: 0.1435, Accuracy: 0.9800
# Train-epoch 11. Iteration 00070, Avg-Loss: 0.1525, Accuracy: 0.9771
# Train-epoch 11. Iteration 00080, Avg-Loss: 0.1574, Accuracy: 0.9725
# Train-epoch 11. Iteration 00090, Avg-Loss: 0.1510, Accuracy: 0.9756
# Train-epoch 11. Iteration 00100, Avg-Loss: 0.1485, Accuracy: 0.9760
# Train-epoch 11. Iteration 00110, Avg-Loss: 0.1792, Accuracy: 0.9673
# Train-epoch 11. Iteration 00120, Avg-Loss: 0.1877, Accuracy: 0.9633
# Train-epoch 11. Iteration 00130, Avg-Loss: 0.1920, Accuracy: 0.9600
# Train-epoch 11. Iteration 00140, Avg-Loss: 0.1950, Accuracy: 0.9586
# Train-epoch 11. Iteration 00150, Avg-Loss: 0.1945, Accuracy: 0.9600
# Train-epoch 11. Iteration 00160, Avg-Loss: 0.1933, Accuracy: 0.9600
# Train-epoch 11. Iteration 00170, Avg-Loss: 0.1909, Accuracy: 0.9600
# Train-epoch 11. Iteration 00180, Avg-Loss: 0.1866, Accuracy: 0.9611
# Train-epoch 11. Iteration 00190, Avg-Loss: 0.1887, Accuracy: 0.9589
# Train-epoch 11. Iteration 00200, Avg-Loss: 0.1877, Accuracy: 0.9590
# Train-epoch 11. Iteration 00210, Avg-Loss: 0.1854, Accuracy: 0.9581
# Train-epoch 11. Iteration 00220, Avg-Loss: 0.1872, Accuracy: 0.9573
# Train-epoch 11. Iteration 00230, Avg-Loss: 0.1855, Accuracy: 0.9574
# Train-epoch 11. Iteration 00240, Avg-Loss: 0.1841, Accuracy: 0.9583
# Train-epoch 11. Iteration 00250, Avg-Loss: 0.1822, Accuracy: 0.9592
# Train-epoch 11. Iteration 00260, Avg-Loss: 0.1805, Accuracy: 0.9600
# Train-epoch 11. Iteration 00270, Avg-Loss: 0.1836, Accuracy: 0.9593
# Train-epoch 11. Iteration 00280, Avg-Loss: 0.1798, Accuracy: 0.9607
# Train-epoch 11. Iteration 00290, Avg-Loss: 0.1782, Accuracy: 0.9621
# Train-epoch 11. Iteration 00300, Avg-Loss: 0.1771, Accuracy: 0.9633
# Train-epoch 11. Iteration 00310, Avg-Loss: 0.1744, Accuracy: 0.9645
# Train-epoch 11. Iteration 00320, Avg-Loss: 0.1795, Accuracy: 0.9625
# Train-epoch 11. Iteration 00330, Avg-Loss: 0.1798, Accuracy: 0.9630
# Train-epoch 11. Iteration 00340, Avg-Loss: 0.1791, Accuracy: 0.9635
# Train-epoch 11. Iteration 00350, Avg-Loss: 0.1757, Accuracy: 0.9646
# Validation-epoch 11. Avg-Loss: 0.3099, Accuracy: 0.9024
# Train-epoch 12. Iteration 00010, Avg-Loss: 0.2308, Accuracy: 0.9200
# Train-epoch 12. Iteration 00020, Avg-Loss: 0.1851, Accuracy: 0.9500
# Train-epoch 12. Iteration 00030, Avg-Loss: 0.1724, Accuracy: 0.9600
# Train-epoch 12. Iteration 00040, Avg-Loss: 0.1654, Accuracy: 0.9600
# Train-epoch 12. Iteration 00050, Avg-Loss: 0.1666, Accuracy: 0.9520
# Train-epoch 12. Iteration 00060, Avg-Loss: 0.1619, Accuracy: 0.9600
# Train-epoch 12. Iteration 00070, Avg-Loss: 0.1556, Accuracy: 0.9629
# Train-epoch 12. Iteration 00080, Avg-Loss: 0.1484, Accuracy: 0.9675
# Train-epoch 12. Iteration 00090, Avg-Loss: 0.1425, Accuracy: 0.9711
# Train-epoch 12. Iteration 00100, Avg-Loss: 0.1387, Accuracy: 0.9740
# Train-epoch 12. Iteration 00110, Avg-Loss: 0.1457, Accuracy: 0.9745
# Train-epoch 12. Iteration 00120, Avg-Loss: 0.1416, Accuracy: 0.9750
# Train-epoch 12. Iteration 00130, Avg-Loss: 0.1447, Accuracy: 0.9754
# Train-epoch 12. Iteration 00140, Avg-Loss: 0.1503, Accuracy: 0.9729
# Train-epoch 12. Iteration 00150, Avg-Loss: 0.1445, Accuracy: 0.9747
# Train-epoch 12. Iteration 00160, Avg-Loss: 0.1432, Accuracy: 0.9738
# Train-epoch 12. Iteration 00170, Avg-Loss: 0.1430, Accuracy: 0.9741
# Train-epoch 12. Iteration 00180, Avg-Loss: 0.1444, Accuracy: 0.9722
# Train-epoch 12. Iteration 00190, Avg-Loss: 0.1468, Accuracy: 0.9716
# Train-epoch 12. Iteration 00200, Avg-Loss: 0.1481, Accuracy: 0.9720
# Train-epoch 12. Iteration 00210, Avg-Loss: 0.1514, Accuracy: 0.9714
# Train-epoch 12. Iteration 00220, Avg-Loss: 0.1479, Accuracy: 0.9727
# Train-epoch 12. Iteration 00230, Avg-Loss: 0.1484, Accuracy: 0.9730
# Train-epoch 12. Iteration 00240, Avg-Loss: 0.1489, Accuracy: 0.9725
# Train-epoch 12. Iteration 00250, Avg-Loss: 0.1484, Accuracy: 0.9728
# Train-epoch 12. Iteration 00260, Avg-Loss: 0.1512, Accuracy: 0.9708
# Train-epoch 12. Iteration 00270, Avg-Loss: 0.1529, Accuracy: 0.9704
# Train-epoch 12. Iteration 00280, Avg-Loss: 0.1548, Accuracy: 0.9707
# Train-epoch 12. Iteration 00290, Avg-Loss: 0.1517, Accuracy: 0.9717
# Train-epoch 12. Iteration 00300, Avg-Loss: 0.1517, Accuracy: 0.9707
# Train-epoch 12. Iteration 00310, Avg-Loss: 0.1499, Accuracy: 0.9716
# Train-epoch 12. Iteration 00320, Avg-Loss: 0.1488, Accuracy: 0.9719
# Train-epoch 12. Iteration 00330, Avg-Loss: 0.1484, Accuracy: 0.9715
# Train-epoch 12. Iteration 00340, Avg-Loss: 0.1500, Accuracy: 0.9694
# Train-epoch 12. Iteration 00350, Avg-Loss: 0.1515, Accuracy: 0.9686
# Validation-epoch 12. Avg-Loss: 0.3435, Accuracy: 0.8750
# Train-epoch 13. Iteration 00010, Avg-Loss: 0.1462, Accuracy: 0.9800
# Train-epoch 13. Iteration 00020, Avg-Loss: 0.1291, Accuracy: 0.9900
# Train-epoch 13. Iteration 00030, Avg-Loss: 0.1275, Accuracy: 0.9800
# Train-epoch 13. Iteration 00040, Avg-Loss: 0.1138, Accuracy: 0.9850
# Train-epoch 13. Iteration 00050, Avg-Loss: 0.1239, Accuracy: 0.9840
# Train-epoch 13. Iteration 00060, Avg-Loss: 0.1158, Accuracy: 0.9800
# Train-epoch 13. Iteration 00070, Avg-Loss: 0.1204, Accuracy: 0.9800
# Train-epoch 13. Iteration 00080, Avg-Loss: 0.1206, Accuracy: 0.9800
# Train-epoch 13. Iteration 00090, Avg-Loss: 0.1180, Accuracy: 0.9822
# Train-epoch 13. Iteration 00100, Avg-Loss: 0.1177, Accuracy: 0.9820
# Train-epoch 13. Iteration 00110, Avg-Loss: 0.1113, Accuracy: 0.9836
# Train-epoch 13. Iteration 00120, Avg-Loss: 0.1112, Accuracy: 0.9817
# Train-epoch 13. Iteration 00130, Avg-Loss: 0.1091, Accuracy: 0.9831
# Train-epoch 13. Iteration 00140, Avg-Loss: 0.1171, Accuracy: 0.9786
# Train-epoch 13. Iteration 00150, Avg-Loss: 0.1142, Accuracy: 0.9787
# Train-epoch 13. Iteration 00160, Avg-Loss: 0.1122, Accuracy: 0.9800
# Train-epoch 13. Iteration 00170, Avg-Loss: 0.1120, Accuracy: 0.9800
# Train-epoch 13. Iteration 00180, Avg-Loss: 0.1134, Accuracy: 0.9800
# Train-epoch 13. Iteration 00190, Avg-Loss: 0.1145, Accuracy: 0.9800
# Train-epoch 13. Iteration 00200, Avg-Loss: 0.1129, Accuracy: 0.9810
# Train-epoch 13. Iteration 00210, Avg-Loss: 0.1135, Accuracy: 0.9810
# Train-epoch 13. Iteration 00220, Avg-Loss: 0.1131, Accuracy: 0.9818
# Train-epoch 13. Iteration 00230, Avg-Loss: 0.1129, Accuracy: 0.9826
# Train-epoch 13. Iteration 00240, Avg-Loss: 0.1146, Accuracy: 0.9817
# Train-epoch 13. Iteration 00250, Avg-Loss: 0.1150, Accuracy: 0.9816
# Train-epoch 13. Iteration 00260, Avg-Loss: 0.1138, Accuracy: 0.9823
# Train-epoch 13. Iteration 00270, Avg-Loss: 0.1153, Accuracy: 0.9822
# Train-epoch 13. Iteration 00280, Avg-Loss: 0.1153, Accuracy: 0.9814
# Train-epoch 13. Iteration 00290, Avg-Loss: 0.1144, Accuracy: 0.9814
# Train-epoch 13. Iteration 00300, Avg-Loss: 0.1158, Accuracy: 0.9807
# Train-epoch 13. Iteration 00310, Avg-Loss: 0.1150, Accuracy: 0.9813
# Train-epoch 13. Iteration 00320, Avg-Loss: 0.1140, Accuracy: 0.9819
# Train-epoch 13. Iteration 00330, Avg-Loss: 0.1155, Accuracy: 0.9812
# Train-epoch 13. Iteration 00340, Avg-Loss: 0.1142, Accuracy: 0.9812
# Train-epoch 13. Iteration 00350, Avg-Loss: 0.1146, Accuracy: 0.9806
# Validation-epoch 13. Avg-Loss: 0.3781, Accuracy: 0.8659
# Train-epoch 14. Iteration 00010, Avg-Loss: 0.1349, Accuracy: 1.0000
# Train-epoch 14. Iteration 00020, Avg-Loss: 0.1530, Accuracy: 0.9900
# Train-epoch 14. Iteration 00030, Avg-Loss: 0.1459, Accuracy: 0.9867
# Train-epoch 14. Iteration 00040, Avg-Loss: 0.1483, Accuracy: 0.9800
# Train-epoch 14. Iteration 00050, Avg-Loss: 0.1539, Accuracy: 0.9760
# Train-epoch 14. Iteration 00060, Avg-Loss: 0.1451, Accuracy: 0.9800
# Train-epoch 14. Iteration 00070, Avg-Loss: 0.1358, Accuracy: 0.9800
# Train-epoch 14. Iteration 00080, Avg-Loss: 0.1270, Accuracy: 0.9825
# Train-epoch 14. Iteration 00090, Avg-Loss: 0.1514, Accuracy: 0.9733
# Train-epoch 14. Iteration 00100, Avg-Loss: 0.1453, Accuracy: 0.9760
# Train-epoch 14. Iteration 00110, Avg-Loss: 0.1391, Accuracy: 0.9782
# Train-epoch 14. Iteration 00120, Avg-Loss: 0.1396, Accuracy: 0.9767
# Train-epoch 14. Iteration 00130, Avg-Loss: 0.1512, Accuracy: 0.9692
# Train-epoch 14. Iteration 00140, Avg-Loss: 0.1455, Accuracy: 0.9714
# Train-epoch 14. Iteration 00150, Avg-Loss: 0.1405, Accuracy: 0.9720
# Train-epoch 14. Iteration 00160, Avg-Loss: 0.1368, Accuracy: 0.9725
# Train-epoch 14. Iteration 00170, Avg-Loss: 0.1367, Accuracy: 0.9729
# Train-epoch 14. Iteration 00180, Avg-Loss: 0.1389, Accuracy: 0.9733
# Train-epoch 14. Iteration 00190, Avg-Loss: 0.1407, Accuracy: 0.9716
# Train-epoch 14. Iteration 00200, Avg-Loss: 0.1420, Accuracy: 0.9710
# Train-epoch 14. Iteration 00210, Avg-Loss: 0.1398, Accuracy: 0.9724
# Train-epoch 14. Iteration 00220, Avg-Loss: 0.1359, Accuracy: 0.9736
# Train-epoch 14. Iteration 00230, Avg-Loss: 0.1336, Accuracy: 0.9748
# Train-epoch 14. Iteration 00240, Avg-Loss: 0.1349, Accuracy: 0.9733
# Train-epoch 14. Iteration 00250, Avg-Loss: 0.1347, Accuracy: 0.9736
# Train-epoch 14. Iteration 00260, Avg-Loss: 0.1350, Accuracy: 0.9723
# Train-epoch 14. Iteration 00270, Avg-Loss: 0.1356, Accuracy: 0.9733
# Train-epoch 14. Iteration 00280, Avg-Loss: 0.1380, Accuracy: 0.9714
# Train-epoch 14. Iteration 00290, Avg-Loss: 0.1359, Accuracy: 0.9717
# Train-epoch 14. Iteration 00300, Avg-Loss: 0.1347, Accuracy: 0.9720
# Train-epoch 14. Iteration 00310, Avg-Loss: 0.1328, Accuracy: 0.9729
# Train-epoch 14. Iteration 00320, Avg-Loss: 0.1326, Accuracy: 0.9731
# Train-epoch 14. Iteration 00330, Avg-Loss: 0.1322, Accuracy: 0.9733
# Train-epoch 14. Iteration 00340, Avg-Loss: 0.1297, Accuracy: 0.9741
# Train-epoch 14. Iteration 00350, Avg-Loss: 0.1295, Accuracy: 0.9737
# Validation-epoch 14. Avg-Loss: 0.3230, Accuracy: 0.8933

# %%
#Confusion Matrix Part
import numpy as np
import matplotlib.pyplot as plt
import itertools
from sklearn.metrics import confusion_matrix

from sklearn.metrics import recall_score
from sklearn.metrics import precision_recall_curve
from sklearn.preprocessing import label_binarize
from sklearn.metrics import f1_score
from sklearn.metrics import precision_score
from sklearn.metrics import average_precision_score
from sklearn.metrics import confusion_matrix
from sklearn import svm, datasets
from sklearn.model_selection import train_test_split
from sklearn.utils.multiclass import unique_labels

import time
import torch
import torch.nn as nn
import torch.nn.functional as F
import torchvision.models as models
import torchvision.transforms as transforms
from PIL import Image
import matplotlib.pyplot as plt
import json, io, requests, string
from torch.utils.data.dataset import Dataset
from torchvision import transforms
import pandas as pd
import numpy as np

class_names = ['Glass', 'Paper', 'Cardboard', 'Plastic', 'Metal', 'Trash' ]


def precisionrecall():
    batchSize = 5
#     model_load = torch.load("D:/trainedmodel_inceptionV3.pth")
    val_loader = torch.utils.data.DataLoader(dataset = valset,
                                             batch_size = batchSize,
                                             shuffle = False) # No need.
    model_load = model

    model_load.eval()


    score_list = []
    label_list = []
    
    
    for (i, (inputs, labels)) in enumerate(val_loader):
        
        inputs = inputs.cuda()
        labels = labels.cuda()

        #           # Forward pass. (Prediction stage)
        scores = model_load(inputs)
        
        #            # Count how many correct in this batch.
        max_scores, max_labels = scores.max(1)
        
#         stores the scores and labels for computation of the precision recall curve
        score_list.append(scores.cpu().tolist())
        label_list.append(labels.view(-1).cpu().tolist())
        
    scoreholder = [[] for i in range(0,6)]

    class_counter = 0
    
    for class_counter in range(0,6):
        for i in score_list:
            for counter in  range(0,len(i)):
                try:
                    scoreholder[class_counter].append(i[counter][class_counter])
                except IndexError:
                    print(i)
                    break


    precision = []

    ## Here we merge the datas of each epoch in tensor form (concantation)
    ypred_list = []
    ytrue_list = []
    print(len(label_list))
    print(len(label_list[0]))
    
    print(len(score_list))
    print(len(score_list[0]))
    print(len(score_list[0][0]))
    
    for element in label_list:
        for subelement in element:

            ytrue_list.append(subelement)

    x = label_binarize(ytrue_list, classes=[0, 1, 2, 3, 4, 5])
    
    print(len(scoreholder[0]))
    print(len(x))
    
    
    precision= [0]*6
    recall = [0]*6
    average_precision = [0] * 6
    for i in range(0,6):
        precision[i], recall[i], _ = precision_recall_curve(x[:, i], np.asarray(scoreholder[i]))

        average_precision[i] = average_precision_score(x[:, i], np.asarray(scoreholder[i]))


    for i in range(0,6):
        plt.step(recall[i], precision[i], label= class_names[i], linewidth = 0.5)
    plt.legend()

    plt.xlabel('Recall')
    plt.ylabel('Precision')
    plt.ylim([0.0, 1.05])
    plt.xlim([0.0, 1.0])
#     plt.title('2-class Precision-Recall curve: AP={0:0.2f}'.format(
#               average_precision[1]))
    plt.savefig('precision-recall-inceptionv3.png', dpi = 720)

    


                          
precisionrecall()
# Out:
# 66
# 5
# 66
# 5
# 6
# 328
# 328

# %%
import torch.nn.functional as F


maxmat = []

valset = torch.utils.data.TensorDataset(imgtensorVal, labeltensorVal)

val_loader = torch.utils.data.DataLoader(dataset = valset,
                                         batch_size = batchSize,
                                         shuffle = False) # No need.
maxe = [0] * 6
val3 = [0]*6
val2 = [[0]]*6

mine = [1] * 6
val4 = [0]*6
val1 = [[0]]*6

picmax = [0] * 6
picmin = [0] * 6
piclist = [[] for i in range(6)]
piclistmax = [[] for i in range(6)]
checker = [[] for i in range(6)]

for (i, (inputs, labels)) in enumerate(val_loader):
   inputs = inputs.cuda()
   labels = labels.cuda()
   scores = model(inputs)
   max_scores, max_labels = scores.max(1)
   probs, indices = (-F.softmax(scores, dim = 1).data).sort()
   probsman = F.softmax(scores, dim = 1)
#    print(probsman)
#    print(-probs)
#    print(max_labels)
   for j in range(len(probsman)):
        k = labels.view(-1)[j].item()
        if probsman[j][k] > maxe[k]:
            picmax[k]= inputs[j]
            piclistmax[k].append(inputs[j])
            maxe[k] = probsman[j][k]
            val3[k] = 5*i + j
            val2[k].append(5*i + j)

   for j in range(len(probsman)):
        k = labels.view(-1)[j].item()
        if probsman[j][k] < mine[k]:
            picmin[k] = inputs[j]
            piclist[k].append(inputs[j])
            checker[k].append(k)
            mine[k] = probsman[j][k]
            val4[k] = 5*i + j
            val1[k].append(5*i + j)
    #         print(probs[j][0])

# %%
id = 4

picmaxclone = []

for j in range(len(picmax)):
    picmaxclone.append(picmax[j].clone())
    
for t, m, s in zip(picmaxclone[id], [0.485, 0.456, 0.406], [0.229, 0.224, 0.225]):
  t.mul_(s).add_(m)
# Re-arrange dimensions so it is height x width x channels.
plt.imshow(picmaxclone[id].cpu().transpose(0,2).transpose(0,1));
plt.grid(False); plt.axis('off');

# %%
id =3

picminclone = []

for j in range(len(picmin)):
    picminclone.append(picmin[j].clone())
    
for t, m, s in zip(picminclone[id], [0.485, 0.456, 0.406], [0.229, 0.224, 0.225]):
  t.mul_(s).add_(m)
# Re-arrange dimensions so it is height x width x channels.
plt.imshow(picminclone[id].cpu().transpose(0,2).transpose(0,1));
plt.grid(False); plt.axis('off');

# %%
id = 5
rank = -2
picminclone = []
for bigcounter in range(6):
    id = bigcounter
    # print(piclist)
    for j in range(len(piclist)):
        picminclone.append(piclist[j][rank].clone())

    for t, m, s in zip(picminclone[id], [0.485, 0.456, 0.406], [0.229, 0.224, 0.225]):
      t.mul_(s).add_(m)
    # Re-arrange dimensions so it is height x width x channels.
    plt.imshow(picminclone[id].cpu().transpose(0,2).transpose(0,1));
    plt.grid(False); plt.axis('off'); plt.figure()

# %%
id = 5
rank = -2
picminclone = []
for bigcounter in range(6):
    id = bigcounter
    # print(piclist)
    for j in range(len(piclistmax)):
        picminclone.append(piclistmax[j][rank].clone())

    for t, m, s in zip(picminclone[id], [0.485, 0.456, 0.406], [0.229, 0.224, 0.225]):
      t.mul_(s).add_(m)
    # Re-arrange dimensions so it is height x width x channels.
    plt.imshow(picminclone[id].cpu().transpose(0,2).transpose(0,1));
    plt.grid(False); plt.axis('off'); plt.figure()

# %%
scoreholder = [[0] for i in range(0,6)]

class_counter = 0
for class_counter in range(0,6):
    for i in y_allscore[-1]:
        for counter in  range(0,len(i)):
            try:
                scoreholder[class_counter].append(i[counter][class_counter].item())
            except IndexError:
                print(i)
                break

# %%
#Confusion Matrix Part
from sklearn import svm, datasets
from sklearn.model_selection import train_test_split
from sklearn.utils.multiclass import unique_labels
import numpy as np
import matplotlib.pyplot as plt
import itertools
from sklearn.metrics import confusion_matrix


normalize = True
tensorino = torch.tensor([1])
ytrue_list = []
for element in y_true:
    tensorino = torch.tensor([1])
    for subelement in element:
#         print(subelement)
        tensorino = torch.cat((tensorino, subelement.cpu()), 0)
    ytrue_list.append(tensorino)
    
ypred_list = []    
for element in y_pred:
    tensorino = torch.tensor([1])
    for subelement in element:
#         print(subelement)
        tensorino = torch.cat((tensorino, subelement.cpu()), 0)
    ypred_list.append(tensorino)
    
# print(tensorino)

print(np.asarray(ytrue_list[-1].tolist()))
class_names = ['Glass', 'Paper', 'Cardboard', 'Plastic', 'Metal', 'Trash' ]
print(confusion_matrix(ytrue_list[-1], ypred_list[-1]))

# plot_confusion_matrix(np.asarray(ytrue_list[-1].tolist()), np.asarray(ypred_list[-1].tolist()), classes=class_names,
#                       normalize=False)
cm = confusion_matrix(ytrue_list[-1],ypred_list[-1])
piun = [0]*6
for i in range(0, cm.shape[1]):
    piun[i] =  np.ndarray.tolist(np.divide(cm[i],np.sum(cm[i])))

cm = np.asarray(piun)
fig, ax = plt.subplots()
im = ax.imshow(cm, interpolation='nearest', cmap = plt.cm.Blues)
ax.figure.colorbar(im, ax=ax)
    # We want to show all ticks...
ax.set(xticks=np.arange(cm.shape[1]),
        yticks=np.arange(cm.shape[0]),
           # ... and label them with the respective list entries
        xticklabels=class_names, yticklabels=class_names,
        title="Confusion Matrix",
        ylabel='True label',
        xlabel='Predicted label')
thresh = cm.max() / 1.5 if normalize else cm.max() / 2
for i,j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
    if normalize:
            plt.text(j, i, "{:0.2f}".format(cm[i, j]),
                     horizontalalignment="center",
                     color="white" if cm[i, j] > thresh else "black")
    else:
        plt.text(j, i, "{:,}".format(cm[i, j]),
                    horizontalalignment="center",
                    color="white" if cm[i, j] > thresh else "black")
plt.xticks( rotation=30)
# print(cm)
# plt.imshow(cm, cmap = plt.cm.Blues)

# %%
from sklearn.metrics import recall_score
from sklearn.metrics import precision_recall_curve
from sklearn.preprocessing import label_binarize
from sklearn.metrics import f1_score
from sklearn.metrics import precision_score
from sklearn.metrics import average_precision_score
from sklearn.metrics import confusion_matrix

precision = []
# print(y_score)
## Here we merge the datas of each epoch in tensor form (concantation)
ypred_list = []
# for element in y_score:
#     tensorino = torch.tensor([1])
#     for subelement in element:
#         tensorino = torch.cat((tensorino, subelement.cpu()), 0)
#     ypred_list.append(tensorino)
    
for element in y_true:
    tensorino = torch.tensor([1])
    for subelement in element:
        tensorino = torch.cat((tensorino, subelement.cpu()), 0)
    ytrue_list.append(tensorino)
    
# print(len(ytrue_list[0]))
    
# truelist = [element.item() for element in y_true[1][350].cpu().flatten()]
# predlist = [element.item() for element in y_pred[1][350].cpu().flatten()]

# print(confusion_matrix(truelist, predlist))

# print(len(y_true))
# print(len(y_true[0]))
x = label_binarize(ytrue_list[-1], classes=[0, 1, 2, 3, 4, 5])
# y = label_binarize(ypred_list[-1], classes=[0, 1, 2, 3, 4, 5])

# print(y[0])
# print(len(y[:,1]))
precision= [0]*6
recall = [0]*6
average_precision = [0] * 6
# print(np.asarray(scoreholder[0]))
for i in range(0,6):
    precision[i], recall[i], _ = precision_recall_curve(x[:, i], np.asarray(scoreholder[i]))

    average_precision[i] = average_precision_score(x[:, i], np.asarray(scoreholder[i]))

# print(len(precision[0]))    
# print(precision)
# print(recall)
# print(average_precision)


# print(x)
# print(y)

# print(recall_score(truelist, predlist, average=None))
# print(precision_score(truelist, predlist, average=None))


ardor = []
ardor_2 = []
precision_list = []

for i in precision:
    for j in i:
        ardor.append(j)
        
for i in recall:
    for j in i:
        ardor_2.append(j) 
        
for i in average_precision:
        precision_list.append(j)  
        
# print(ardor)
for i in range(0,6):
    plt.step(recall[i], precision[i], label= class_names[i], linewidth = 0.5)
plt.legend()
# plt.fill_between(recall, precision, alpha=0.2, color='b')

plt.xlabel('Recall')
plt.ylabel('Precision')
plt.ylim([0.0, 1.05])
plt.xlim([0.0, 1.0])
plt.title('2-class Precision-Recall curve: AP={0:0.2f}'.format(
          average_precision[1]))
plt.savefig('precision-recall.png', dpi = 720)

# %%
y_pred[1][350].cpu()

# %%
y_true[1][350].cpu()

# %%
torch.save(model, "D:/trainedmodel_inceptionV3.pth")

# %%
#Confusion Matrix Part
import numpy as np
import matplotlib.pyplot as plt
import itertools
from sklearn.metrics import confusion_matrix

from sklearn.metrics import recall_score
from sklearn.metrics import precision_recall_curve
from sklearn.preprocessing import label_binarize
from sklearn.metrics import f1_score
from sklearn.metrics import precision_score
from sklearn.metrics import average_precision_score
from sklearn.metrics import confusion_matrix
from sklearn import svm, datasets
from sklearn.model_selection import train_test_split
from sklearn.utils.multiclass import unique_labels

import time
import torch
import torch.nn as nn
import torch.nn.functional as F
import torchvision.models as models
import torchvision.transforms as transforms
from PIL import Image
import matplotlib.pyplot as plt
import json, io, requests, string
from torch.utils.data.dataset import Dataset
from torchvision import transforms
import pandas as pd
import numpy as np

class_names = ['Glass', 'Paper', 'Cardboard', 'Plastic', 'Metal', 'Trash' ]

score_list = []
label_list = []
ypred_list = []
y_pred = []
ytrue_list = []

def precisionrecall():
    batchSize = 5
    
    val_loader = torch.utils.data.DataLoader(dataset = valset,
                                             batch_size = batchSize,
                                             shuffle = False) # No need.
    model_load = model
    model_load = torch.load("D:/trainedmodel_inceptionV3.pth")
    model_load.eval()



    
    
    for (i, (inputs, labels)) in enumerate(val_loader):
        
        inputs = inputs.cuda()
        labels = labels.cuda()

        #           # Forward pass. (Prediction stage)
        scores = model_load(inputs)
        
        #            # Count how many correct in this batch.
        max_scores, max_labels = scores.max(1)
        y_pred.append(max_labels.cpu().tolist())

#         stores the scores and labels for computation of the precision recall curve
        score_list.append(scores.cpu().tolist())
        label_list.append(labels.view(-1).cpu().tolist())
        
    scoreholder = [[] for i in range(0,6)]

    class_counter = 0
    
    for class_counter in range(0,6):
        for i in score_list:
            for counter in  range(0,len(i)):
                try:
                    scoreholder[class_counter].append(i[counter][class_counter])
                except IndexError:
                    print(i)
                    break
                    
    for i in y_pred:
        for counter in  i:
            ypred_list.append(counter)
               


    precision = []

    ## Here we merge the datas of each epoch in tensor form (concantation)

    print(len(label_list))
    print(len(label_list[0]))
    
    print(len(score_list))
    print(len(score_list[0]))
    print(len(score_list[0][0]))
    
    for element in label_list:
        for subelement in element:

            ytrue_list.append(subelement)

    x = label_binarize(ytrue_list, classes=[0, 1, 2, 3, 4, 5])
    
    print(len(scoreholder[0]))
    print(len(x))
    
    
    precision= [0]*6
    recall = [0]*6
    average_precision = [0] * 6
    for i in range(0,6):
        precision[i], recall[i], _ = precision_recall_curve(x[:, i], np.asarray(scoreholder[i]))

        average_precision[i] = average_precision_score(x[:, i], np.asarray(scoreholder[i]))


    for i in range(0,6):
        plt.step(recall[i], precision[i], label= class_names[i], linewidth = 0.5)
    plt.legend()

    plt.xlabel('Recall')
    plt.ylabel('Precision')
    plt.ylim([0.0, 1.05])
    plt.xlim([0.0, 1.0])
#     plt.title('2-class Precision-Recall curve: AP={0:0.2f}'.format(
#               average_precision[1]))
    plt.savefig('precision-recall-inceptionv3.png', dpi = 720)

    


                          
precisionrecall()
# Out:
# 66
# 5
# 66
# 5
# 6
# 328
# 328

# %%
#Confusion Matrix Part
from sklearn import svm, datasets
from sklearn.model_selection import train_test_split
from sklearn.utils.multiclass import unique_labels
import numpy as np
import matplotlib.pyplot as plt
import itertools
from sklearn.metrics import confusion_matrix


normalize = True
tensorino = torch.tensor([1])
ytrue_list = []

for element in label_list:
        for subelement in element:

            ytrue_list.append(subelement)

    
# print(tensorino)

print(np.asarray(ytrue_list))
class_names = ['Glass', 'Paper', 'Cardboard', 'Plastic', 'Metal', 'Trash' ]
print(confusion_matrix(ytrue_list, ypred_list))

# plot_confusion_matrix(np.asarray(ytrue_list[-1].tolist()), np.asarray(ypred_list[-1].tolist()), classes=class_names,
#                       normalize=False)
cm = confusion_matrix(ytrue_list,ypred_list)
piun = [0]*6
for i in range(0, cm.shape[1]):
    piun[i] =  np.ndarray.tolist(np.divide(cm[i],np.sum(cm[i])))

cm = np.asarray(piun)
fig, ax = plt.subplots()
im = ax.imshow(cm, interpolation='nearest', cmap = plt.cm.Blues)
ax.figure.colorbar(im, ax=ax)
    # We want to show all ticks...
ax.set(xticks=np.arange(cm.shape[1]),
        yticks=np.arange(cm.shape[0]),
           # ... and label them with the respective list entries
        xticklabels=class_names, yticklabels=class_names,
        title="Confusion Matrix",
        ylabel='True label',
        xlabel='Predicted label')
thresh = cm.max() / 1.5 if normalize else cm.max() / 2
for i,j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
    if normalize:
            plt.text(j, i, "{:0.2f}".format(cm[i, j]),
                     horizontalalignment="center",
                     color="white" if cm[i, j] > thresh else "black")
    else:
        plt.text(j, i, "{:,}".format(cm[i, j]),
                    horizontalalignment="center",
                    color="white" if cm[i, j] > thresh else "black")
plt.xticks( rotation=30)
print(cm)
plt.imshow(cm, cmap = plt.cm.Blues)
# Out:
# [2 3 0 0 0 2 4 5 0 1 2 4 1 0 0 0 1 5 3 2 3 1 0 3 0 3 3 4 1 1 0 1 2 1 0 3 3
#  4 4 4 3 1 2 0 4 4 2 0 5 1 1 1 2 2 3 0 3 2 4 4 0 4 0 5 0 2 0 2 1 3 2 5 4 1
#  1 1 1 0 1 4 0 2 3 4 2 0 3 1 0 1 0 1 3 2 4 1 0 3 1 1 2 0 2 3 3 0 4 3 2 3 1
#  0 3 2 3 3 2 2 4 4 0 2 2 2 1 4 0 1 3 0 4 3 0 1 1 3 5 3 3 1 0 3 1 3 3 0 4 0
#  1 0 0 1 4 3 4 3 0 1 0 0 3 2 0 3 3 4 2 3 5 0 1 0 3 0 1 3 3 1 0 5 2 1 1 2 0
#  1 5 1 4 2 1 1 2 4 1 4 3 1 4 1 3 1 4 2 1 0 1 4 1 4 2 2 1 2 3 4 5 1 1 3 2 0
#  5 0 1 1 2 1 1 1 3 0 3 0 5 1 1 3 2 0 0 0 1 0 0 0 2 1 4 4 1 0 0 5 1 5 1 1 5
#  4 2 1 1 4 1 2 3 0 4 1 4 3 3 4 5 2 4 3 5 1 1 1 4 3 4 4 1 2 4 2 0 3 3 4 3 1
#  4 1 1 4 4 0 4 3 4 3 4 4 4 4 1 1 3 1 0 1 3 0 4 2 0 4 2 3 0 1 0 0]
# [[56  0  0  3  8  0]
#  [ 0 79  0  0  0  3]
#  [ 1  1 43  1  0  0]
#  [ 4  1  0 53  1  1]
#  [ 6  1  0  3 46  0]
#  [ 0  0  1  1  2 13]]
# [[0.8358209  0.         0.         0.04477612 0.11940299 0.        ]
#  [0.         0.96341463 0.         0.         0.         0.03658537]
#  [0.02173913 0.02173913 0.93478261 0.02173913 0.         0.        ]
#  [0.06666667 0.01666667 0.         0.88333333 0.01666667 0.01666667]
#  [0.10714286 0.01785714 0.         0.05357143 0.82142857 0.        ]
#  [0.         0.         0.05882353 0.05882353 0.11764706 0.76470588]]
